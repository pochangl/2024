# %% [markdown]
# # 作業

# %% [markdown]
# ## 1. a038. 數字翻轉
# https://zerojudge.tw/ShowProblem?problemid=a038

# %%
'0'
'01'

# %%
### ValueError
int('')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 ### ValueError
# ----> 2 int('')
#
# ValueError: invalid literal for int() with base 10: ''

# %%
int('1')
# Out:
# 1

# %% [markdown]
# ### 解法
# * for loop
# * slicing
# * reverse

# %%
a = [1, 2, 3, 4, 5]

# %%
# 作法 1 for loop
tmp = a[0]
a[0] = a[-1]
a[-1] = tmp

tmp = a[1]
a[1] = a[-2]
a[-2] = tmp

a
# Out:
# [1, 2, 3, 4, 5]

# %%
# 作法 2

# %%
a = [1, 2, 3, 4, 5]
a
# Out:
# [1, 2, 3, 4, 5]

# %%
# 作法2 slicing
a[::-1]
# Out:
# [5, 4, 3, 2, 1]

# %%
a = [1, 2, 3, 4, 5]
a
# Out:
# [1, 2, 3, 4, 5]

# %%
# 作法 3
a.reverse()

# %%
a
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## 2. k860. 重複數字
# https://zerojudge.tw/ShowProblem?problemid=k860

# %% [markdown]
# ### 使用 count 的問題

# %%
a = [1, 1, 2]

# %%
a.count(1, 0, 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 a.count(1, 0, 1)
#
# TypeError: list.count() takes exactly one argument (3 given)

# %% [markdown]
# 上面的錯誤訊息是指函式只有一個參數, 但程式碼給了三個參數
# 下面舉個例

# %%
def c(a):
    # c 需要1個參數
    print(a)

# %%
c(1)
# Out:
# 1

# %%
c(1, 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 c(1, 2)
#
# TypeError: c() takes 1 positional argument but 2 were given

# %% [markdown]
# # count 的用法

# %%
a.count(1)
# Out:
# 2

# %%
a.count(1) == 2
# Out:
# True

# %%
a.count(1) == 1
# Out:
# False

# %%
if a.count(1) == 2:
    print('1 有 2 個')
# Out:
# 1 有 2 個

# %%
a = [ 1, 1, 2]

for i in set(a):
    print(i)
# Out:
# 1
# 2

# %%
set(a)
# Out:
# {1, 2}

# %% [markdown]
# ## 3. k861. 驗證費氏數列
# https://zerojudge.tw/ShowProblem?problemid=k861

# %% [markdown]
# 0 1 1 2 3 5 (3 + 5)

# %%
nums = [0, 1, 1, 3, 4]

# %%
nums[0] == 0
# Out:
# True

# %%
nums[1] == 1
# Out:
# True

# %%
nums[2] == nums[0] + nums[1]
# Out:
# True

# %%
nums[3] == nums[1] + nums[2]
# Out:
# False

# %%
nums[4] == nums[2] + nums[3]
# Out:
# True

# %% [markdown]
# 費式數列的第3項開始的規則
# ```python
# for n in ....:
#    nums[n] = nums[n - 1] + nums[n-2]
# ```
# n 是從 2 到長度 - 1

# %%
len(nums)
# Out:
# 5

# %%
nums[4]
# Out:
# 4

# %%
nums[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 nums[5]
#
# IndexError: list index out of range

# %%
list(range(2, 5))
# Out:
# [2, 3, 4]

# %% [markdown]
# ```python
# for n in range(2, 5):
#     .....
# ```

# %% [markdown]
# # 上次上課的內容

# %% [markdown]
# * numpy
# * pandas

# %%
import pandas

# %% [markdown]
# ## CSV
# comma-separated values
#
# 像 ｅｘｃｅｌ　每一行用換行隔開
#
# 每一欄用 , 隔開

# %% [markdown]
# ### Pandas 讀入 CSV

# %%
df = pandas.read_csv('addresses.csv',)

# %%
df
# Out:
#                     John       Doe                 120 jefferson st.  \
# 0                   Jack  McGinnis                      220 hobo Av.
# 1          John "Da Man"    Repici                 120 Jefferson St.
# 2                Stephen     Tyler  7452 Terrace "At the Plaza" road
# 3                    NaN  Blankman                               NaN
# 4  Joan "the bone", Anne       Jet               9th, at Terrace plc
#
#      Riverside   NJ   08075
# 0        Phila   PA    9119
# 1    Riverside   NJ    8075
# 2     SomeTown   SD   91234
# 3     SomeTown   SD     298
# 4  Desert City   CO     123

# %%
df = pandas.read_csv('addresses.csv', header=None)
df
# Out:
#                        0         1                                 2  \
# 0                   John       Doe                 120 jefferson st.
# 1                   Jack  McGinnis                      220 hobo Av.
# 2          John "Da Man"    Repici                 120 Jefferson St.
# 3                Stephen     Tyler  7452 Terrace "At the Plaza" road
# 4                    NaN  Blankman                               NaN
# 5  Joan "the bone", Anne       Jet               9th, at Terrace plc
#
#              3    4      5
# 0    Riverside   NJ   8075
# 1        Phila   PA   9119
# 2    Riverside   NJ   8075
# 3     SomeTown   SD  91234
# 4     SomeTown   SD    298
# 5  Desert City   CO    123

# %% [markdown]
# ### pandas 複寫 column 名稱

# %%
df.columns = ['first name', 'last name','address', 'city', 'state', 'zipcode']

# %%
df
# Out:
#               first name last name                           address  \
# 0                   John       Doe                 120 jefferson st.
# 1                   Jack  McGinnis                      220 hobo Av.
# 2          John "Da Man"    Repici                 120 Jefferson St.
# 3                Stephen     Tyler  7452 Terrace "At the Plaza" road
# 4                    NaN  Blankman                               NaN
# 5  Joan "the bone", Anne       Jet               9th, at Terrace plc
#
#           city state  zipcode
# 0    Riverside    NJ     8075
# 1        Phila    PA     9119
# 2    Riverside    NJ     8075
# 3     SomeTown    SD    91234
# 4     SomeTown    SD      298
# 5  Desert City    CO      123

# %% [markdown]
# ###　Dataframe 取得某一欄位

# %%
df['first name']
# Out:
# 0                     John
# 1                     Jack
# 2            John "Da Man"
# 3                  Stephen
# 4                      NaN
# 5    Joan "the bone", Anne
# Name: first name, dtype: object

# %%
df['state']
# Out:
# 0     NJ
# 1     PA
# 2     NJ
# 3     SD
# 4     SD
# 5     CO
# Name: state, dtype: object

# %%
df['city']
# Out:
# 0      Riverside
# 1          Phila
# 2      Riverside
# 3       SomeTown
# 4       SomeTown
# 5    Desert City
# Name: city, dtype: object

# %% [markdown]
# ### pandas Search
# 找出 city 等於 Riverside 的資料

# %%
df[df['city'] == 'Riverside']
# Out:
#       first name last name            address       city state  zipcode
# 0           John       Doe  120 jefferson st.  Riverside    NJ     8075
# 2  John "Da Man"    Repici  120 Jefferson St.  Riverside    NJ     8075

# %%
df['city'] == 'Riverside'
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# Name: city, dtype: bool

# %%
search_result = df[df['city'] == 'Riverside']
search_result
# Out:
#       first name last name            address       city state  zipcode
# 0           John       Doe  120 jefferson st.  Riverside    NJ     8075
# 2  John "Da Man"    Repici  120 Jefferson St.  Riverside    NJ     8075

# %%
### 新增欄位

# %%
df['age'] = 0

# %%
df
# Out:
#               first name last name                           address  \
# 0                   John       Doe                 120 jefferson st.
# 1                   Jack  McGinnis                      220 hobo Av.
# 2          John "Da Man"    Repici                 120 Jefferson St.
# 3                Stephen     Tyler  7452 Terrace "At the Plaza" road
# 4                    NaN  Blankman                               NaN
# 5  Joan "the bone", Anne       Jet               9th, at Terrace plc
#
#           city state  zipcode  age
# 0    Riverside    NJ     8075    0
# 1        Phila    PA     9119    0
# 2    Riverside    NJ     8075    0
# 3     SomeTown    SD    91234    0
# 4     SomeTown    SD      298    0
# 5  Desert City    CO      123    0

# %%
df[df['first name'] == 'John']
# Out:
#   first name last name            address       city state  zipcode  age
# 0       John       Doe  120 jefferson st.  Riverside    NJ     8075    0

# %%
# Out:
# C:\Users\charlie\AppData\Local\Temp\ipykernel_2556\142507977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['first name'] == 'John']['age'] = 10

# %%
import pandas

# %%
df = pandas.read_csv('grades.csv')
df
# Out:
#     Last name      "First name"                  "SSN"          "Test1"  \
# 0     Alfalfa        "Aloysius"          "123-45-6789"             40.0
# 1      Alfred      "University"          "123-12-1234"             41.0
# 2       Gerty          "Gramma"          "567-89-0123"             41.0
# 3     Android        "Electric"          "087-65-4321"             42.0
# 4     Bumpkin            "Fred"          "456-78-9012"             43.0
# 5      Rubble           "Betty"          "234-56-7890"             44.0
# 6      Noshow           "Cecil"          "345-67-8901"             45.0
# 7        Buff             "Bif"          "632-79-9939"             46.0
# 8     Airpump          "Andrew"          "223-45-6789"             49.0
# 9      Backus             "Jim"          "143-12-1234"             48.0
# 10  Carnivore             "Art"          "565-89-0123"             44.0
# 11      Dandy             "Jim"          "087-75-4321"             47.0
# 12   Elephant             "Ima"          "456-71-9012"             45.0
# 13   Franklin           "Benny"          "234-56-2890"             50.0
# 14     George             "Boy"          "345-67-3901"             40.0
# 15  Heffalump          "Harvey"          "632-79-9439"             30.0
#
#      "Test2"   "Test3"   "Test4"   "Final"  "Grade"
# 0       90.0     100.0      83.0      49.0     "D-"
# 1       97.0      96.0      97.0      48.0     "D+"
# 2       80.0      60.0      40.0      44.0      "C"
# 3       23.0      36.0      45.0      47.0     "B-"
# 4       78.0      88.0      77.0      45.0     "A-"
# 5       90.0      80.0      90.0      46.0     "C-"
# 6       11.0      -1.0       4.0      43.0      "F"
# 7       20.0      30.0      40.0      50.0     "B+"
# 8        1.0      90.0     100.0      83.0      "A"
# 9        1.0      97.0      96.0      97.0     "A+"
# 10       1.0      80.0      60.0      40.0     "D+"
# 11       1.0      23.0      36.0      45.0     "C+"
# 12       1.0      78.0      88.0      77.0     "B-"
# 13       1.0      90.0      80.0      90.0     "B-"
# 14       1.0      11.0      -1.0       4.0      "B"
# 15       1.0      20.0      30.0      40.0      "C"

# %%
df.columns = ['Last name', 'First name', 'SSN', 'Test1', 'Test2', 'Test3', 'Test4', 'Final', 'Grade']

# %%
df
# Out:
#     Last name        First name                    SSN  Test1  Test2  Test3  \
# 0     Alfalfa        "Aloysius"          "123-45-6789"   40.0   90.0  100.0
# 1      Alfred      "University"          "123-12-1234"   41.0   97.0   96.0
# 2       Gerty          "Gramma"          "567-89-0123"   41.0   80.0   60.0
# 3     Android        "Electric"          "087-65-4321"   42.0   23.0   36.0
# 4     Bumpkin            "Fred"          "456-78-9012"   43.0   78.0   88.0
# 5      Rubble           "Betty"          "234-56-7890"   44.0   90.0   80.0
# 6      Noshow           "Cecil"          "345-67-8901"   45.0   11.0   -1.0
# 7        Buff             "Bif"          "632-79-9939"   46.0   20.0   30.0
# 8     Airpump          "Andrew"          "223-45-6789"   49.0    1.0   90.0
# 9      Backus             "Jim"          "143-12-1234"   48.0    1.0   97.0
# 10  Carnivore             "Art"          "565-89-0123"   44.0    1.0   80.0
# 11      Dandy             "Jim"          "087-75-4321"   47.0    1.0   23.0
# 12   Elephant             "Ima"          "456-71-9012"   45.0    1.0   78.0
# 13   Franklin           "Benny"          "234-56-2890"   50.0    1.0   90.0
# 14     George             "Boy"          "345-67-3901"   40.0    1.0   11.0
# 15  Heffalump          "Harvey"          "632-79-9439"   30.0    1.0   20.0
#
#     Test4  Final    Grade
# 0    83.0   49.0     "D-"
# 1    97.0   48.0     "D+"
# 2    40.0   44.0      "C"
# 3    45.0   47.0     "B-"
# 4    77.0   45.0     "A-"
# 5    90.0   46.0     "C-"
# 6     4.0   43.0      "F"
# 7    40.0   50.0     "B+"
# 8   100.0   83.0      "A"
# 9    96.0   97.0     "A+"
# 10   60.0   40.0     "D+"
# 11   36.0   45.0     "C+"
# 12   88.0   77.0     "B-"
# 13   80.0   90.0     "B-"
# 14   -1.0    4.0      "B"
# 15   30.0   40.0      "C"

# %%
df['total'] = df['Test1'] + df['Test2'] + df['Test3'] + df['Test4'] + df['Final']

# %%
df['average'] = df['total'] / 5

# %%
df
# Out:
#     Last name        First name                    SSN  Test1  Test2  Test3  \
# 0     Alfalfa        "Aloysius"          "123-45-6789"   40.0   90.0  100.0
# 1      Alfred      "University"          "123-12-1234"   41.0   97.0   96.0
# 2       Gerty          "Gramma"          "567-89-0123"   41.0   80.0   60.0
# 3     Android        "Electric"          "087-65-4321"   42.0   23.0   36.0
# 4     Bumpkin            "Fred"          "456-78-9012"   43.0   78.0   88.0
# 5      Rubble           "Betty"          "234-56-7890"   44.0   90.0   80.0
# 6      Noshow           "Cecil"          "345-67-8901"   45.0   11.0   -1.0
# 7        Buff             "Bif"          "632-79-9939"   46.0   20.0   30.0
# 8     Airpump          "Andrew"          "223-45-6789"   49.0    1.0   90.0
# 9      Backus             "Jim"          "143-12-1234"   48.0    1.0   97.0
# 10  Carnivore             "Art"          "565-89-0123"   44.0    1.0   80.0
# 11      Dandy             "Jim"          "087-75-4321"   47.0    1.0   23.0
# 12   Elephant             "Ima"          "456-71-9012"   45.0    1.0   78.0
# 13   Franklin           "Benny"          "234-56-2890"   50.0    1.0   90.0
# 14     George             "Boy"          "345-67-3901"   40.0    1.0   11.0
# 15  Heffalump          "Harvey"          "632-79-9439"   30.0    1.0   20.0
#
#     Test4  Final    Grade  total  average
# 0    83.0   49.0     "D-"  362.0     72.4
# 1    97.0   48.0     "D+"  379.0     75.8
# 2    40.0   44.0      "C"  265.0     53.0
# 3    45.0   47.0     "B-"  193.0     38.6
# 4    77.0   45.0     "A-"  331.0     66.2
# 5    90.0   46.0     "C-"  350.0     70.0
# 6     4.0   43.0      "F"  102.0     20.4
# 7    40.0   50.0     "B+"  186.0     37.2
# 8   100.0   83.0      "A"  323.0     64.6
# 9    96.0   97.0     "A+"  339.0     67.8
# 10   60.0   40.0     "D+"  225.0     45.0
# 11   36.0   45.0     "C+"  152.0     30.4
# 12   88.0   77.0     "B-"  289.0     57.8
# 13   80.0   90.0     "B-"  311.0     62.2
# 14   -1.0    4.0      "B"   55.0     11.0
# 15   30.0   40.0      "C"  121.0     24.2

# %% [markdown]
# ```python
# df.average.plot()
# 有條件等於
# df['average'].plot()
# 推薦第二種寫法
# ```

# %%
df['average'].plot()
# Out:
# <Axes: >

# %%
import plotly.express as px

# %%
# jupyter 不能呈的用這行
import plotly.io as pio
pio.renderers.default = "iframe"

# %%
px.line(df['average'])
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_170.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
px.line(df['Final'])
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_179.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
px.line(df['average'])
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_183.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
px.scatter(y=df['average'], x=df.index)
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_182.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df
# Out:
#     Last name        First name                    SSN  Test1  Test2  Test3  \
# 0     Alfalfa        "Aloysius"          "123-45-6789"   40.0   90.0  100.0
# 1      Alfred      "University"          "123-12-1234"   41.0   97.0   96.0
# 2       Gerty          "Gramma"          "567-89-0123"   41.0   80.0   60.0
# 3     Android        "Electric"          "087-65-4321"   42.0   23.0   36.0
# 4     Bumpkin            "Fred"          "456-78-9012"   43.0   78.0   88.0
# 5      Rubble           "Betty"          "234-56-7890"   44.0   90.0   80.0
# 6      Noshow           "Cecil"          "345-67-8901"   45.0   11.0   -1.0
# 7        Buff             "Bif"          "632-79-9939"   46.0   20.0   30.0
# 8     Airpump          "Andrew"          "223-45-6789"   49.0    1.0   90.0
# 9      Backus             "Jim"          "143-12-1234"   48.0    1.0   97.0
# 10  Carnivore             "Art"          "565-89-0123"   44.0    1.0   80.0
# 11      Dandy             "Jim"          "087-75-4321"   47.0    1.0   23.0
# 12   Elephant             "Ima"          "456-71-9012"   45.0    1.0   78.0
# 13   Franklin           "Benny"          "234-56-2890"   50.0    1.0   90.0
# 14     George             "Boy"          "345-67-3901"   40.0    1.0   11.0
# 15  Heffalump          "Harvey"          "632-79-9439"   30.0    1.0   20.0
#
#     Test4  Final    Grade  total  average
# 0    83.0   49.0     "D-"  362.0     72.4
# 1    97.0   48.0     "D+"  379.0     75.8
# 2    40.0   44.0      "C"  265.0     53.0
# 3    45.0   47.0     "B-"  193.0     38.6
# 4    77.0   45.0     "A-"  331.0     66.2
# 5    90.0   46.0     "C-"  350.0     70.0
# 6     4.0   43.0      "F"  102.0     20.4
# 7    40.0   50.0     "B+"  186.0     37.2
# 8   100.0   83.0      "A"  323.0     64.6
# 9    96.0   97.0     "A+"  339.0     67.8
# 10   60.0   40.0     "D+"  225.0     45.0
# 11   36.0   45.0     "C+"  152.0     30.4
# 12   88.0   77.0     "B-"  289.0     57.8
# 13   80.0   90.0     "B-"  311.0     62.2
# 14   -1.0    4.0      "B"   55.0     11.0
# 15   30.0   40.0      "C"  121.0     24.2

# %%
df['Grade'] = df['Grade'].apply(lambda x: x.strip().replace('"', ''))

# %%
df['pass'] = df['Grade'] != 'F'
df
# Out:
#     Last name        First name                    SSN  Test1  Test2  Test3  \
# 0     Alfalfa        "Aloysius"          "123-45-6789"   40.0   90.0  100.0
# 1      Alfred      "University"          "123-12-1234"   41.0   97.0   96.0
# 2       Gerty          "Gramma"          "567-89-0123"   41.0   80.0   60.0
# 3     Android        "Electric"          "087-65-4321"   42.0   23.0   36.0
# 4     Bumpkin            "Fred"          "456-78-9012"   43.0   78.0   88.0
# 5      Rubble           "Betty"          "234-56-7890"   44.0   90.0   80.0
# 6      Noshow           "Cecil"          "345-67-8901"   45.0   11.0   -1.0
# 7        Buff             "Bif"          "632-79-9939"   46.0   20.0   30.0
# 8     Airpump          "Andrew"          "223-45-6789"   49.0    1.0   90.0
# 9      Backus             "Jim"          "143-12-1234"   48.0    1.0   97.0
# 10  Carnivore             "Art"          "565-89-0123"   44.0    1.0   80.0
# 11      Dandy             "Jim"          "087-75-4321"   47.0    1.0   23.0
# 12   Elephant             "Ima"          "456-71-9012"   45.0    1.0   78.0
# 13   Franklin           "Benny"          "234-56-2890"   50.0    1.0   90.0
# 14     George             "Boy"          "345-67-3901"   40.0    1.0   11.0
# 15  Heffalump          "Harvey"          "632-79-9439"   30.0    1.0   20.0
#
#     Test4  Final Grade  total  average   pass
# 0    83.0   49.0    D-  362.0     72.4   True
# 1    97.0   48.0    D+  379.0     75.8   True
# 2    40.0   44.0     C  265.0     53.0   True
# 3    45.0   47.0    B-  193.0     38.6   True
# 4    77.0   45.0    A-  331.0     66.2   True
# 5    90.0   46.0    C-  350.0     70.0   True
# 6     4.0   43.0     F  102.0     20.4  False
# 7    40.0   50.0    B+  186.0     37.2   True
# 8   100.0   83.0     A  323.0     64.6   True
# 9    96.0   97.0    A+  339.0     67.8   True
# 10   60.0   40.0    D+  225.0     45.0   True
# 11   36.0   45.0    C+  152.0     30.4   True
# 12   88.0   77.0    B-  289.0     57.8   True
# 13   80.0   90.0    B-  311.0     62.2   True
# 14   -1.0    4.0     B   55.0     11.0   True
# 15   30.0   40.0     C  121.0     24.2   True

# %%
df.to_csv('new grade.csv')

# %%
px.scatter(y=df['average'], x=df.index, color=df['pass'])
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_205.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
